# %% [markdown]
# <a href="https://colab.research.google.com/github/mikieoo/big-data-analysis/blob/main/matplotlib_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

sales=pd.Series([781,650,705,406,580,450,550,640])
sales.index=['A','B','C','D','E','F','G','H']

sales
# Out:
# A    781
# B    650
# C    705
# D    406
# E    580
# F    450
# G    550
# H    640
# dtype: int64

# %%
sales[(sales > 700) | (sales < 500)]
# Out:
# A    781
# C    705
# D    406
# F    450
# dtype: int64

# %%
sales[sales > sales['B']]
# Out:
# A    781
# C    705
# dtype: int64

# %%
sales[sales < 600].index
# Out:
# Index(['D', 'E', 'F', 'G'], dtype='object')

# %%
sales_increase=sales[sales < 600] * 1.2
sales_increase
# Out:
# D    116.9856
# E    167.0976
# F    129.6576
# G    158.4576
# dtype: float64

# %%
print('평균:', sales.mean())
print('표준편차:', sales.std())
print('합계:', sales.sum())
# Out:
# 평균: 595.25
# 평균: 125.77843330918972
# 평균: 4762

# %%
sales[['A','C']]=[810,820]
sales
# Out:
# A    810
# B    650
# C    820
# D    406
# E    580
# F    450
# G    550
# H    640
# dtype: int64

# %%
sales['J']=400
sales
# Out:
# A    810
# B    650
# C    820
# D    406
# E    580
# F    450
# G    550
# H    640
# J    400
# dtype: int64

# %%
sales.drop('J',inplace=True)

# %%
sales
# Out:
# A    810
# B    650
# C    820
# D    406
# E    580
# F    450
# G    550
# H    640
# dtype: int64

# %%
sales2=sales.copy()
sales2 = sales + 500
sales2
# Out:
# A    1310
# B    1150
# C    1320
# D     906
# E    1080
# F     950
# G    1050
# H    1140
# dtype: int64

# %%
hobby=pd.Series(['등산','낚시','골프','수영','등산','등산','낚시','수영','등산','낚시','수영','골프'])
hobby
# Out:
# 0     등산
# 1     낚시
# 2     골프
# 3     수영
# 4     등산
# 5     등산
# 6     낚시
# 7     수영
# 8     등산
# 9     낚시
# 10    수영
# 11    골프
# dtype: object

# %%
cnt=hobby.value_counts()
# Out:
# 등산    4
# 낚시    3
# 수영    3
# 골프    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

cnt=hobby.value_counts()

fig,axes=plt.subplots(nrows=1,ncols=2)

cnt.plot.bar(ax=axes[0])
cnt.plot.pie(ax=axes[1])
# Out:
# <Axes: ylabel='count'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45210 (\N{HANGUL SYLLABLE NAGG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
import numpy as np

data = [10,20,30,40,50]

mean = np.mean(data)
std = np.std(data)

print('원본 데이터: ',data)

print('[표준화 결과]')
standard = (data-mean)/std
print(standard)

print(['정규화 결과'])
normalization = data - np.min(data) / np.max(data) - np.min(data)
print(normalization)
# Out:
# 원본 데이터:  [10, 20, 30, 40, 50]
# [표준화 결과]
# [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]
# ['정규화 결과']
# [-0.2  9.8 19.8 29.8 39.8]
