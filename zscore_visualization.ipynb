# %% [markdown]
# <a href="https://colab.research.google.com/github/mikieoo/big-data-analysis/blob/main/zscore_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore

plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

subjects=['국어','수학','영어','과학','사회']
scores=[85,90,70,95,80]

z_scores=zscore(scores)

num_vars=len(subjects)
angles=np.linspace(0,2*np.pi,num_vars,endpoint=False).tolist()
z_scores=z_scores.tolist()

z_scores+=z_scores[:1]
angles+=angles[:1]

fig,ax = plt.subplots(figsize=(6,6),subplot_kw=dict(polar=True))
ax.plot(angles,z_scores,color='blue',linewidth=2)
ax.fill(angles,z_scores,color='skyblue',alpha=0.4)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(subjects)

ax.set_title('학생의 과목별 표준 점수 (z-scroe)',size=15)
ax.set_yticklabels(['-2','-1','0','1','2'])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-31672fcb23ee>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['-2','-1','0','1','2'])
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# <ipython-input-2-31672fcb23ee>:29: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-2-31672fcb23ee>:29: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# <ipython-input-2-31672fcb23ee>:29: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
